# %% [markdown]
# # Top 10 Big 0 Interview Questions (Amazon, Facebook, Apple and Microsoft)

# %% [markdown]
# > What is the runtime of the below code?

# %% [markdown]
# ## 1. Product and Sum

# %%
def foo(array):
    sum = 0
    product = 1

    for i in array:
        sum += i

    for i in array:
        product *= i

    print('Sum = ' + str(sum) + ', Product = ' + str(product))

# %% [markdown]
# Time Complexity: `O(N)`

# %% [markdown]
# ## 2. Print Pairs

# %%
def printPairs(array):
    for i in array:
        for j in array:
            print(str(i) + ', ' + str(j))

# %% [markdown]
# Time Complexity: `O(N^2)`

# %% [markdown]
# ## 3. Print Unordered Pairs

# %%
def printUnorderedPairs(array):
    for i in range(0, len(array)):
        for j in range(i + 1, len(array)):
            print(array[i] + ', ' + array[j])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Time Complexity: `O(N^2)`

# %% [markdown]
# ## 4. Print Unordered Pairs 2 Arrays

# %%
def printUnorderedPairs(arrayA, arrayB):
    for i in range(len(arrayA)):
        for j in range(len(arrayB)):
            if arrayA[i] < arrayB[j]:
                print(str(arrayA[i]) + ', ' + str(arrayB[j]))

# %% [markdown]
# Time Complexity: `O(AB)`

# %% [markdown]
# ## 5. Print Unordered Pairs 2 Arrays 100000 Units

# %%
def printUnorderedPairs(arrayA, arrayB):
    for i in range(len(arrayA)):
        for j in range(len(arrayB)):
            for k in range(0, 100000):
                print(str(arrayA[i]) + ', ' + str(arrayB[j]))

# %% [markdown]
# Time Complexity: `O(AB)`

# %% [markdown]
# ## 6. Reverse

# %%
def reverse(array):
    for i in range(0, int(len(array)/2)):
        other = len(array) - i - 1
        temp = array[i]
        array[i] = array[other]
        array[other] = temp

    print(array)

# %% [markdown]
# Time Complexity: `O(N)`

# %% [markdown]
# ## 7. O(N) Equivalents

# %% [markdown]
# > Which of the following are equivalent to O(N)? Why?

# %% [markdown]
# - O(N + P), where P < N/2 &rarr; O(N) &#x2611;
# - O(2N) &rarr; O(N) &#9745;
# - O(N + Log N) &rarr; O(N) &#9745;
# - O(N + N Log N) &#x2612;
# - O(N + M) &#9746;

# %% [markdown]
# ![image.png](time_complexity_chart.jpg)
